# %% [markdown]
# <a href="https://colab.research.google.com/github/ufbfung/mimic-fhir/blob/main/load_and_profile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview
# In this notebook, I will be exploring the mimic IV demo database on FHIR and perhaps create some interesting functions in python for it.

# %%
# !wget -r -N -c -np https://physionet.org/files/mimic-iv-fhir-demo/2.0/
# Out:
# --2024-01-15 17:19:38--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/index.html’
#
# physionet.org/files     [ <=>                ]     584  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-01-15 17:19:38 (57.7 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/index.html’ saved [584]
#
# Loading robots.txt; please ignore errors.
# --2024-01-15 17:19:38--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# 2024-01-15 17:19:38 (6.95 MB/s) - ‘physionet.org/robots.txt’ saved [22/22]
#
# --2024-01-15 17:19:38--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/index.html’
#
# physionet.org/files     [ <=>                ]   2.99K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-01-15 17:19:38 (412 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/index.html’ saved [3061]
#
# --2024-01-15 17:19:38--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/LICENSE.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 25815 (25K) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/LICENSE.txt’
#
# physionet.org/files 100%[===================>]  25.21K  --.-KB/s    in 0.008s
#
# 2024-01-15 17:19:38 (3.08 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/LICENSE.txt’ saved [25815/25815]
#
# --2024-01-15 17:19:38--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/SHA256SUMS.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2267 (2.2K) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/SHA256SUMS.txt’
#
# physionet.org/files 100%[===================>]   2.21K  --.-KB/s    in 0s
#
# 2024-01-15 17:19:38 (519 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/SHA256SUMS.txt’ saved [2267/2267]
#
# --2024-01-15 17:19:38--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Condition.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3250455 (3.1M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Condition.ndjson’
#
# physionet.org/files 100%[===================>]   3.10M  1.21MB/s    in 2.6s
#
# 2024-01-15 17:19:41 (1.21 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Condition.ndjson’ saved [3250455/3250455]
#
# --2024-01-15 17:19:41--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Encounter.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 494573 (483K) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Encounter.ndjson’
#
# physionet.org/files 100%[===================>] 482.98K  1.22MB/s    in 0.4s
#
# 2024-01-15 17:19:41 (1.22 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Encounter.ndjson’ saved [494573/494573]
#
# --2024-01-15 17:19:41--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/EncounterICU.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 136404 (133K) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/EncounterICU.ndjson’
#
# physionet.org/files 100%[===================>] 133.21K  --.-KB/s    in 0.09s
#
# 2024-01-15 17:19:42 (1.44 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/EncounterICU.ndjson’ saved [136404/136404]
#
# --2024-01-15 17:19:42--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Location.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20268 (20K) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Location.ndjson’
#
# physionet.org/files 100%[===================>]  19.79K  --.-KB/s    in 0.004s
#
# 2024-01-15 17:19:42 (4.92 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Location.ndjson’ saved [20268/20268]
#
# --2024-01-15 17:19:42--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Medication.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19683905 (19M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Medication.ndjson’
#
# physionet.org/files 100%[===================>]  18.77M  1.25MB/s    in 15s
#
# 2024-01-15 17:19:57 (1.26 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Medication.ndjson’ saved [19683905/19683905]
#
# --2024-01-15 17:19:57--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationAdministration.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 35873598 (34M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationAdministration.ndjson’
#
# physionet.org/files 100%[===================>]  34.21M  1.34MB/s    in 27s
#
# 2024-01-15 17:20:24 (1.26 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationAdministration.ndjson’ saved [35873598/35873598]
#
# --2024-01-15 17:20:24--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationAdministrationICU.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 26186200 (25M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationAdministrationICU.ndjson’
#
# physionet.org/files 100%[===================>]  24.97M  1.32MB/s    in 19s
#
# 2024-01-15 17:20:43 (1.30 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationAdministrationICU.ndjson’ saved [26186200/26186200]
#
# --2024-01-15 17:20:43--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationDispense.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12455867 (12M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationDispense.ndjson’
#
# physionet.org/files 100%[===================>]  11.88M  1.34MB/s    in 8.9s
#
# 2024-01-15 17:20:52 (1.33 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationDispense.ndjson’ saved [12455867/12455867]
#
# --2024-01-15 17:20:52--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationRequest.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19164989 (18M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationRequest.ndjson’
#
# physionet.org/files 100%[===================>]  18.28M  1.32MB/s    in 14s
#
# 2024-01-15 17:21:06 (1.29 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/MedicationRequest.ndjson’ saved [19164989/19164989]
#
# --2024-01-15 17:21:06--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationChartevents.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 622443441 (594M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationChartevents.ndjson’
#
# physionet.org/files 100%[===================>] 593.61M  1.42MB/s    in 7m 22s
#
# 2024-01-15 17:28:28 (1.34 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationChartevents.ndjson’ saved [622443441/622443441]
#
# --2024-01-15 17:28:28--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationDatetimeevents.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13472117 (13M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationDatetimeevents.ndjson’
#
# physionet.org/files 100%[===================>]  12.85M  1.01MB/s    in 11s
#
# 2024-01-15 17:28:39 (1.20 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationDatetimeevents.ndjson’ saved [13472117/13472117]
#
# --2024-01-15 17:28:39--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationLabevents.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 137896108 (132M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationLabevents.ndjson’
#
# physionet.org/files 100%[===================>] 131.51M  1.34MB/s    in 99s
#
# 2024-01-15 17:30:18 (1.33 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationLabevents.ndjson’ saved [137896108/137896108]
#
# --2024-01-15 17:30:18--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroOrg.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 343172 (335K) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroOrg.ndjson’
#
# physionet.org/files 100%[===================>] 335.13K  1.35MB/s    in 0.2s
#
# 2024-01-15 17:30:18 (1.35 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroOrg.ndjson’ saved [343172/343172]
#
# --2024-01-15 17:30:18--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroSusc.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1101679 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroSusc.ndjson’
#
# physionet.org/files 100%[===================>]   1.05M  1.32MB/s    in 0.8s
#
# 2024-01-15 17:30:19 (1.32 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroSusc.ndjson’ saved [1101679/1101679]
#
# --2024-01-15 17:30:19--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroTest.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1734938 (1.7M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroTest.ndjson’
#
# physionet.org/files 100%[===================>]   1.65M  1.36MB/s    in 1.2s
#
# 2024-01-15 17:30:20 (1.36 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationMicroTest.ndjson’ saved [1734938/1734938]
#
# --2024-01-15 17:30:20--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationOutputevents.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8895641 (8.5M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationOutputevents.ndjson’
#
# physionet.org/files 100%[===================>]   8.48M  1.40MB/s    in 6.1s
#
# 2024-01-15 17:30:26 (1.40 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ObservationOutputevents.ndjson’ saved [8895641/8895641]
#
# --2024-01-15 17:30:26--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Organization.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 532 [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Organization.ndjson’
#
# physionet.org/files 100%[===================>]     532  --.-KB/s    in 0s
#
# 2024-01-15 17:30:26 (374 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Organization.ndjson’ saved [532/532]
#
# --2024-01-15 17:30:26--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Patient.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 161650 (158K) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Patient.ndjson’
#
# physionet.org/files 100%[===================>] 157.86K  --.-KB/s    in 0.09s
#
# 2024-01-15 17:30:26 (1.63 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Patient.ndjson’ saved [161650/161650]
#
# --2024-01-15 17:30:26--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Procedure.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 499729 (488K) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Procedure.ndjson’
#
# physionet.org/files 100%[===================>] 488.02K  1.54MB/s    in 0.3s
#
# 2024-01-15 17:30:27 (1.54 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Procedure.ndjson’ saved [499729/499729]
#
# --2024-01-15 17:30:27--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ProcedureICU.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1259694 (1.2M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ProcedureICU.ndjson’
#
# physionet.org/files 100%[===================>]   1.20M  1.44MB/s    in 0.8s
#
# 2024-01-15 17:30:28 (1.44 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/ProcedureICU.ndjson’ saved [1259694/1259694]
#
# --2024-01-15 17:30:28--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Specimen.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6806438 (6.5M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Specimen.ndjson’
#
# physionet.org/files 100%[===================>]   6.49M  1.38MB/s    in 4.7s
#
# 2024-01-15 17:30:32 (1.39 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Specimen.ndjson’ saved [6806438/6806438]
#
# --2024-01-15 17:30:32--  https://physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/SpecimenLab.ndjson
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6806438 (6.5M) [text/plain]
# Saving to: ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/SpecimenLab.ndjson’
#
# physionet.org/files 100%[===================>]   6.49M  1.33MB/s    in 4.9s
#
# 2024-01-15 17:30:37 (1.32 MB/s) - ‘physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/SpecimenLab.ndjson’ saved [6806438/6806438]
#
# FINISHED --2024-01-15 17:30:37--
# Total wall clock time: 10m 59s
# Downloaded: 27 files, 876M in 10m 58s (1.33 MB/s)

# %%
# Navigate the file path
base_path = 'physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir'
patient_path = os.path.join(base_path, 'Patient.ndjson')
condition_path = os.path.join(base_path, 'Condition.ndjson')

print(patient_path)

import os

list_of_fhir_files = os.listdir(base_path)

for file in list_of_fhir_files:
    print(file)
# Out:
# physionet.org/files/mimic-iv-fhir-demo/2.0/mimic-fhir/Patient.ndjson
# MedicationAdministration.ndjson
# Condition.ndjson
# ObservationMicroSusc.ndjson
# Organization.ndjson
# ObservationMicroOrg.ndjson
# ObservationDatetimeevents.ndjson
# ObservationChartevents.ndjson
# ObservationOutputevents.ndjson
# MedicationRequest.ndjson
# SpecimenLab.ndjson
# Medication.ndjson
# Specimen.ndjson
# Procedure.ndjson
# Location.ndjson
# EncounterICU.ndjson
# ObservationLabevents.ndjson
# Encounter.ndjson
# ObservationMicroTest.ndjson
# MedicationDispense.ndjson
# MedicationAdministrationICU.ndjson
# Patient.ndjson
# ProcedureICU.ndjson
# index.html

# %%
# !pip install fhir.resources
from fhir.resources.patient import Patient
from fhir.resources.observation import Observation
from fhir.resources.R4B.condition import Condition
# Out:
# Requirement already satisfied: fhir.resources in /usr/local/lib/python3.10/dist-packages (7.1.0)
# Requirement already satisfied: pydantic[email]<3.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from fhir.resources) (2.5.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic[email]<3.0,>=2.0.1->fhir.resources) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /usr/local/lib/python3.10/dist-packages (from pydantic[email]<3.0,>=2.0.1->fhir.resources) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic[email]<3.0,>=2.0.1->fhir.resources) (4.9.0)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pydantic[email]<3.0,>=2.0.1->fhir.resources) (2.1.0.post1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email-validator>=2.0.0->pydantic[email]<3.0,>=2.0.1->fhir.resources) (2.4.2)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email-validator>=2.0.0->pydantic[email]<3.0,>=2.0.1->fhir.resources) (3.6)

# %%
import json
import pandas as pd
from datetime import datetime

def create_fhir_object(resource_data):
    resource_type = resource_data.get("resourceType")

    if resource_type == "Patient":
        return Patient.parse_obj(resource_data)
    if resource_type == "Condition":
        return Condition.parse_obj(resource_data)
    elif resource_type == "Observation":
        return Observation.parse_obj(resource_data)

def parse_fhir_records(file_path):
    fhir_objects = []

    with open(file_path, 'r') as file:
        for line in file:
            resource_data = json.loads(line)
            fhir_object = create_fhir_object(resource_data)
            fhir_objects.append(fhir_object)

    return fhir_objects

def calculate_age_with_offset(birthdate, offset_years=150):
    today = datetime.now().date()

    # Calculate the difference in years
    age = today.year - birthdate.year - ((today.month, today.day) < (birthdate.month, birthdate.day))

    # Apply the offset
    age_with_offset = age - offset_years
    return age_with_offset

# Usage
patients = parse_fhir_records(patient_path)
conditions = parse_fhir_records(condition_path)

conditions[0]
# Out:
# Condition(resource_type='Condition', fhir_comments=None, id='0002fff8-11c5-5d6d-975a-b926a13bb02b', implicitRules=None, implicitRules__ext=None, language=None, language__ext=None, meta=Meta(resource_type='Meta', fhir_comments=None, extension=None, id=None, lastUpdated=datetime.datetime(2022, 5, 24, 15, 51, 35, 263000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), lastUpdated__ext=None, profile=['http://fhir.mimic.mit.edu/StructureDefinition/mimic-condition'], profile__ext=None, security=None, source='#CexDBHtjfcg8Ti57', source__ext=None, tag=None, versionId='1', versionId__ext=None), contained=None, extension=None, modifierExtension=None, text=None, abatementAge=None, abatementDateTime=None, abatementDateTime__ext=None, abatementPeriod=None, abatementRange=None, abatementString=None, abatementString__ext=None, asserter=None, bodySite=None, category=[CodeableConcept(resource_type='CodeableConcept', fhir_comments=None, extension=None, id=None, coding=[Coding(resource_type='Coding', fhir_comments=None, extension=None, id=None, code='encounter-diagnosis', code__ext=None, display=None, display__ext=None, system='http://terminology.hl7.org/CodeSystem/condition-category', system__ext=None, userSelected=None, userSelected__ext=None, version=None, version__ext=None)], text=None, text__ext=None)], clinicalStatus=None, code=CodeableConcept(resource_type='CodeableConcept', fhir_comments=None, extension=None, id=None, coding=[Coding(resource_type='Coding', fhir_comments=None, extension=None, id=None, code='Z8546', code__ext=None, display='Personal history of malignant neoplasm of prostate', display__ext=None, system='http://fhir.mimic.mit.edu/CodeSystem/diagnosis-icd10', system__ext=None, userSelected=None, userSelected__ext=None, version=None, version__ext=None)], text=None, text__ext=None), encounter=Reference(resource_type='Reference', fhir_comments=None, extension=None, id=None, display=None, display__ext=None, identifier=None, reference='Encounter/ca52755d-7780-524a-a5f8-6c5d2fc2136a', reference__ext=None, type=None, type__ext=None), evidence=None, identifier=[Identifier(resource_type='Identifier', fhir_comments=None, extension=None, id=None, assigner=None, period=None, system='http://fhir.mimic.mit.edu/identifier/condition', system__ext=None, type=None, use=None, use__ext=None, value='28108313-4-Z8546', value__ext=None)], note=None, onsetAge=None, onsetDateTime=None, onsetDateTime__ext=None, onsetPeriod=None, onsetRange=None, onsetString=None, onsetString__ext=None, recordedDate=None, recordedDate__ext=None, recorder=None, severity=None, stage=None, subject=Reference(resource_type='Reference', fhir_comments=None, extension=None, id=None, display=None, display__ext=None, identifier=None, reference='Patient/b410dd44-7d65-56f9-974f-2751e8aa80e2', reference__ext=None, type=None, type__ext=None), verificationStatus=None)

# %%
from collections import Counter

def profile_conditions(conditions):
    code_counts = Counter()
    patient_conditions = {}
    encounter_conditions = {}

    for condition in conditions:
        # Extract code and display
        code = condition.code.coding[0].code
        display = condition.code.coding[0].display
        code_counts[(code, display)] += 1

        # Count conditions per patient
        patient_id = condition.subject.reference
        patient_conditions.setdefault(patient_id, set()).add(code)

        # Count conditions per encounter
        encounter_id = condition.encounter.reference
        encounter_conditions.setdefault(encounter_id, set()).add(code)

    # Top 10 most prevalent codes along with their display
    top_10_codes = pd.DataFrame(code_counts.most_common(10), columns=['Code_Display', 'Count'])
    top_10_codes[['Code', 'Display']] = pd.DataFrame(top_10_codes['Code_Display'].tolist(), index=top_10_codes.index)

    # Average number of conditions per patient
    avg_conditions_per_patient = sum(len(codes) for codes in patient_conditions.values()) / len(patient_conditions)

     # Number of codes per encounter
    codes_per_encounter = {encounter: len(codes) for encounter, codes in encounter_conditions.items()}

    # Average number of codes per encounter
    avg_codes_per_encounter = sum(codes_per_encounter.values()) / len(codes_per_encounter) if codes_per_encounter else 0

    return top_10_codes[['Code', 'Display', 'Count']], avg_conditions_per_patient, avg_codes_per_encounter

# Example usage:
top_10_codes, avg_conditions_per_patient, avg_codes_per_encounter = profile_conditions(conditions)

# %%
print(top_10_codes)
print(avg_conditions_per_patient)
print(avg_codes_per_encounter)
# Out:
#      Code                                            Display  Count
# 0    4019                 Unspecified essential hypertension     67
# 1    E785                        Hyperlipidemia, unspecified     54
# 2    2724               Other and unspecified hyperlipidemia     51
# 3  Z87891            Personal history of nicotine dependence     35
# 4   I2510  Atherosclerotic heart disease of native corona...     34
# 5     I10                   Essential (primary) hypertension     33
# 6   42731                                Atrial fibrillation     33
# 7    E039                        Hypothyroidism, unspecified     33
# 8   25000  Diabetes mellitus without mention of complicat...     32
# 9    Z794                 Long term (current) use of insulin     32
# 30.52
# 15.897338403041825

# %%
# Find all conditions related to a specific patient

# Specify the patient
pat_id = 'Patient/b410dd44-7d65-56f9-974f-2751e8aa80e2'

pat_conditions = []

for condition in conditions:
    if condition.subject.reference == pat_id:
        pat_conditions.append(condition)

# Print list of conditions
##count = 1
#for condition in pat_conditions:
#    print("Count: ", count,"\n")
#    print(condition.code.coding[0].display,"\n")
#    print(condition.code.coding[0].code, "\n")
#    print(condition.subject.reference, "\n")
#    count += 1

# Create a list of conditions for that patient
conditions_data = []
for condition in pat_conditions:
    condition_data = {
        'Count': conditions.index(condition) + 1,
        'Display': condition.code.coding[0].display,
        'Code': condition.code.coding[0].code,
        'Subject Reference': condition.subject.reference
    }
    conditions_data.append(condition_data)

# Convert to df
conditions_df = pd.DataFrame(conditions_data)

# Print df
conditions_df.head()
# Out:
#    Count                                            Display   Code  \
# 0      1  Personal history of malignant neoplasm of pros...  Z8546
# 1     42              Personal history of hodgkin's disease  V1072
# 2     73  Long term (current) use of antithrombotics/ant...  Z7902
# 3    105              Asthma, unspecified type, unspecified  49390
# 4    152               Other and unspecified hyperlipidemia   2724
#
#                               Subject Reference
# 0  Patient/b410dd44-7d65-56f9-974f-2751e8aa80e2
# 1  Patient/b410dd44-7d65-56f9-974f-2751e8aa80e2
# 2  Patient/b410dd44-7d65-56f9-974f-2751e8aa80e2
# 3  Patient/b410dd44-7d65-56f9-974f-2751e8aa80e2
# 4  Patient/b410dd44-7d65-56f9-974f-2751e8aa80e2

# %%
import pandas as pd
import json

# Function to parse a single patient record from FHIR format
def parse_patient_record(record):
    patient_data = {
        'id': record['id'],
        'gender': record['gender'],
        'birthDate': record['birthDate'],
        'maritalStatus': record.get('maritalStatus', {}).get('coding', [{}])[0].get('code', None),
        'race': None,
        'ethnicity': None,
        'birthSex': None
    }

    # Parsing extensions for race, ethnicity, and birthSex
    for extension in record.get('extension', []):
        if extension['url'] == 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race':
            patient_data['race'] = extension['extension'][0]['valueCoding']['display']
        elif extension['url'] == 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity':
            patient_data['ethnicity'] = extension['extension'][0]['valueCoding']['display']
        elif extension['url'] == 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex':
            patient_data['birthSex'] = extension['valueCode']

    return patient_data

# Function to parse a single observation record
def parse_observation_record(record):
    observation_data = {
        'id': record.get('id', None),
        'status': record.get('status', None),
        'category_code': record.get('category', [{}])[0].get('coding', [{}])[0].get('code', None),
        'test_code': record.get('code', {}).get('coding', [{}])[0].get('code', None),
        'test_name': record.get('code', {}).get('coding', [{}])[0].get('display', None),
        'patient_reference': record.get('subject', {}).get('reference', None),
        'encounter_reference': record.get('encounter', {}).get('reference', None),
        'effectiveDateTime': record.get('effectiveDateTime', None),
        'value': None,
        'unit': None
    }

    # Check if 'valueQuantity' exists before accessing it
    if 'valueQuantity' in record:
        observation_data['value'] = record['valueQuantity'].get('value', None)
        observation_data['unit'] = record['valueQuantity'].get('unit', None)

    return observation_data

def find_observations_for_patient(df, patient_ref):
    """
    Function to find all observation resources for a specific patient.

    Parameters:
    df (DataFrame): The DataFrame containing observation data.
    patient_ref (str): The patient reference to filter by.

    Returns:
    DataFrame: A DataFrame containing only the observations for the specified patient.
    """
    filtered_df = df[df['patient_reference'] == patient_ref]
    return filtered_df

specific_patient_ref = "Patient/9c3ebb7e-d087-519e-bea4-31c3d4aac7ff"
observations_for_patient = find_observations_for_patient(df, specific_patient_ref)

# To view the results
observations_for_patient

# Read the file for patients
patients = []
with open('Patient.ndjson', 'r') as file:
    for line in file:
        json_record = json.loads(line)
        patients.append(parse_patient_record(json_record))

# Reading the file for observations
observations = []
with open('ObservationLabevents.ndjson', 'r') as file:
    for line in file:
        json_record = json.loads(line)
        observations.append(parse_observation_record(json_record))

# Converting both lists to a dataframe
patient_df = pd.DataFrame(patients)
observation_df = pd.DataFrame(observations)

# Using the main web app

# Identify the patient of interest
specific_patient_ref = "Patient/9c3ebb7e-d087-519e-bea4-31c3d4aac7ff"

# Get all observations for that patient
observations_for_patient = find_observations_for_patient(observation_df, specific_patient_ref)

# %% [markdown]
# # Goals for turning this into a web app
#
# - Upload the patient and lab files to github
# - Organize all the functions into a single section in this colab notebook
# - Remove any unnecessary artifacts in the notebook to keep it organized
# - Send all the code to chatGPT to convert to streamlit so I can deploy it as a web app
